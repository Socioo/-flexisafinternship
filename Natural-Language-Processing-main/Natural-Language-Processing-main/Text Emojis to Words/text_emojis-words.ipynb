# %%
import pandas as pd
import emoji

# Larger dataset with various emojis
data = {
    'Text': [
        "I am so happy today 😊",
        "She looks sad 😢",
        "That was a funny joke 😂",
        "I am feeling confused 😕",
        "It's a big surprise 😲",
        "Oh no! I'm shocked 😱",
        "This is amazing ❤️",
        "He is angry 😡",
        "That made me laugh 🤣",
        "I don't know what to say 😐",
        "She just gave me a gift 🎁",
        "They are celebrating 🎉",
        "It's raining heavily 🌧️",
        "Good morning! ☀️",
        "I love ice cream 🍦",
        "Let's go for a ride 🚗",
        "He is studying 📚",
        "They are travelling by plane ✈️",
        "Cooking dinner 🍲",
        "Time to sleep 😴"
    ]
}

# Create a pandas DataFrame
df = pd.DataFrame(data)

# Function to convert emojis to words
def convert_emoji_to_words(text):
    return emoji.demojize(text, delimiters=(" ", " "))

# Apply the function to the dataset
df['Converted_Text'] = df['Text'].apply(convert_emoji_to_words)

# Display the original and converted text side by side
df[['Text', 'Converted_Text']]
# Out:
#                                Text  \
# 0             I am so happy today 😊
# 1                   She looks sad 😢
# 2           That was a funny joke 😂
# 3           I am feeling confused 😕
# 4             It's a big surprise 😲
# 5              Oh no! I'm shocked 😱
# 6                This is amazing ❤️
# 7                     He is angry 😡
# 8              That made me laugh 🤣
# 9        I don't know what to say 😐
# 10        She just gave me a gift 🎁
# 11           They are celebrating 🎉
# 12          It's raining heavily 🌧️
# 13                 Good morning! ☀️
# 14               I love ice cream 🍦
# 15            Let's go for a ride 🚗
# 16                 He is studying 📚
# 17  They are travelling by plane ✈️
# 18                 Cooking dinner 🍲
# 19                  Time to sleep 😴
#
#                                        Converted_Text
# 0   I am so happy today  smiling_face_with_smiling...
# 1                         She looks sad  crying_face
# 2      That was a funny joke  face_with_tears_of_joy
# 3               I am feeling confused  confused_face
# 4               It's a big surprise  astonished_face
# 5         Oh no! I'm shocked  face_screaming_in_fear
# 6                         This is amazing  red_heart
# 7                          He is angry  enraged_face
# 8   That made me laugh  rolling_on_the_floor_laugh...
# 9             I don't know what to say  neutral_face
# 10             She just gave me a gift  wrapped_gift
# 11                They are celebrating  party_popper
# 12             It's raining heavily  cloud_with_rain
# 13                                Good morning!  sun
# 14                  I love ice cream  soft_ice_cream
# 15                   Let's go for a ride  automobile
# 16                             He is studying  books
# 17            They are travelling by plane  airplane
# 18                       Cooking dinner  pot_of_food
# 19                      Time to sleep  sleeping_face

# %%
# Save the results to a CSV file
df.to_csv('emoji_to_words.csv', index=False)
